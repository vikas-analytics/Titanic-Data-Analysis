# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop(columns=['deck'],inplace = True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
df.shape
# Out:
# (891, 14)

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.shape
# Out:
# (712, 14)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    str
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    str
#  8   class        182 non-null    category
#  9   who          182 non-null    str
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    str
#  13  alive        182 non-null    str
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 18.2 KB

# %%
df['age']=df['age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    str
#  3   age          712 non-null    int64
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    str
#  8   class        712 non-null    category
#  9   who          712 non-null    str
#  10  adult_male   712 non-null    bool
#  11  embark_town  712 non-null    str
#  12  alive        712 non-null    str
#  13  alone        712 non-null    bool
# dtypes: bool(2), category(1), float64(1), int64(5), str(5)
# memory usage: 69.0 KB

# %%
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 885         0       3  female   39      0      5  29.1250        Q   Third
# 886         0       2    male   27      0      0  13.0000        S  Second
# 887         1       1  female   19      0      0  30.0000        S   First
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# survived        2
# pclass          3
# sex             2
# age            60
# sibsp           4
# parch           4
# fare           64
# embarked        3
# class           3
# who             3
# adult_male      2
# deck            7
# embark_town     3
# alive           2
# alone           2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 671 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     671 non-null    int64
#  1   pclass       671 non-null    int64
#  2   sex          671 non-null    str
#  3   age          671 non-null    int64
#  4   sibsp        671 non-null    int64
#  5   parch        671 non-null    int64
#  6   fare         671 non-null    float64
#  7   embarked     671 non-null    str
#  8   class        671 non-null    category
#  9   who          671 non-null    str
#  10  adult_male   671 non-null    bool
#  11  embark_town  671 non-null    str
#  12  alive        671 non-null    str
#  13  alone        671 non-null    bool
# dtypes: bool(2), category(1), float64(1), int64(5), str(5)
# memory usage: 65.0 KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  671.000000  671.000000  671.000000  671.000000  671.000000  671.000000
# mean     0.417288    2.223547   29.737705    0.539493    0.457526   35.836916
# std      0.493479    0.846827   14.732431    0.948450    0.872926   54.193827
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   16.100000
# 75%      1.000000    3.000000   39.000000    1.000000    1.000000   35.077100
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %%
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 883         0       2    male   28      0      0  10.5000        S  Second
# 885         0       3  female   39      0      5  29.1250        Q   Third
# 887         1       1  female   19      0      0  30.0000        S   First
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 671 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     671 non-null    int64
#  1   pclass       671 non-null    int64
#  2   sex          671 non-null    str
#  3   age          671 non-null    int64
#  4   sibsp        671 non-null    int64
#  5   parch        671 non-null    int64
#  6   fare         671 non-null    float64
#  7   embarked     671 non-null    str
#  8   class        671 non-null    category
#  9   who          671 non-null    str
#  10  adult_male   671 non-null    bool
#  11  embark_town  671 non-null    str
#  12  alive        671 non-null    str
#  13  alone        671 non-null    bool
# dtypes: bool(2), category(1), float64(1), int64(5), str(5)
# memory usage: 65.0 KB

# %%
df.to_csv('titanic_data_csv',index = True)

# %%
df=pd.read_csv('titanic_data_csv')
df
# Out:
#      Unnamed: 0  survived  pclass     sex  age  sibsp  parch     fare  \
# 0             0         0       3    male   22      1      0   7.2500
# 1             1         1       1  female   38      1      0  71.2833
# 2             2         1       3  female   26      0      0   7.9250
# 3             3         1       1  female   35      1      0  53.1000
# 4             4         0       3    male   35      0      0   8.0500
# ..          ...       ...     ...     ...  ...    ...    ...      ...
# 666         883         0       2    male   28      0      0  10.5000
# 667         885         0       3  female   39      0      5  29.1250
# 668         887         1       1  female   19      0      0  30.0000
# 669         889         1       1    male   26      0      0  30.0000
# 670         890         0       3    male   32      0      0   7.7500
#
#     embarked   class    who  adult_male  embark_town alive  alone
# ...

# %%
df.to_csv('titanic.data.csv',index = True)

# %%
# Exploratory Data Analysis (EDA)

# %%
sns.boxplot(x=df["fare"])
# Out:
# <Axes: xlabel='fare'>

# %%
df.corr(numeric_only=True)
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.034945 -0.249003  0.107565  0.023735  0.134472
# pclass     -0.034945  1.000000 -0.308071 -0.108677  0.043773 -0.319088
# age        -0.249003 -0.308071  1.000000 -0.157540 -0.273923 -0.091764
# sibsp       0.107565 -0.108677 -0.157540  1.000000  0.249651  0.283610
# parch       0.023735  0.043773 -0.273923  0.249651  1.000000  0.387327
# fare        0.134472 -0.319088 -0.091764  0.283610  0.387327  1.000000
# adult_male -0.587878 -0.122996  0.336602 -0.148509 -0.184812 -0.111285
# alone      -0.121942  0.070044  0.209834 -0.625957 -0.546336 -0.295835
#
#             adult_male     alone
# survived     -0.587878 -0.121942
# pclass       -0.122996  0.070044
# age           0.336602  0.209834
# sibsp        -0.148509 -0.625957
# parch        -0.184812 -0.546336
# fare         -0.111285 -0.295835
# adult_male    1.000000  0.195659
# alone         0.195659  1.000000

# %%
df.sort_values(by='fare',ascending = False)
# Out:
#      survived  pclass     sex  age  sibsp  parch   fare embarked  class  \
# 679         1       1    male   36      0      1  512.0        C  First
# 737         1       1    male   35      0      0  512.0        C  First
# 88          1       1  female   23      3      2  263.0        S  First
# 27          0       1    male   19      3      2  263.0        S  First
# 438         0       1    male   64      1      4  263.0        S  First
# ..        ...     ...     ...  ...    ...    ...    ...      ...    ...
# 75          0       3    male   25      0      0    7.0        S  Third
# 699         0       3    male   42      0      0    7.0        S  Third
# 872         0       1    male   33      0      0    5.0        S  First
# 263         0       1    male   40      0      0    0.0        S  First
# 806         0       1    male   39      0      0    0.0        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex  age  sibsp  parch  fare embarked  class    who  \
# 835         1       1  female   39      1      1  83.0        C  First  woman
# 853         1       1  female   16      0      1  39.0        S  First  woman
# 857         1       1    male   51      0      0  26.0        S  First    man
# 862         1       1  female   48      0      0  25.0        S  First  woman
# 867         0       1    male   31      0      0  50.0        S  First    man
# 871         1       1  female   47      1      1  52.0        S  First  woman
# 872         0       1    male   33      0      0   5.0        S  First    man
# 879         1       1  female   56      0      1  83.0        C  First  woman
# 887         1       1  female   19      0      0  30.0        S  First  woman
# 889         1       1    male   26      0      0  30.0        C  First    man
#
#      adult_male deck  embark_town alive  alone
# 835       False    E    Cherbourg   yes  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
1.survival by Gender

# %%
sns.countplot(x='survived', data=df,hue = 'sex')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# from the above data it state that female survived more than the man

# %%
2. Survival by Passenger Class

Chart: Count Plot

# %%
sns.countplot(x='sex',hue='class',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
3. Age Distribution

Chart: Histogram + KDE

# %%
sns.histplot(data = df,x='age',kde=True,hue = 'sex' , palette={'male':'red','female':'purple'})
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
4. Embarkation Analysis

Chart: Count Plot

# %%
sns.countplot(x='embarked', data=df,hue = 'sex' , palette = ['red','green'])
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
5.Correlation Heatmap

Chart: Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %%
6.Age Outliers

Chart: Box Plot

# %%
sns.boxplot(x = df['age'],palette=['red'])
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_10776\2379581831.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df['age'],palette=['red'])
# <Axes: xlabel='age'>

# %%
7.Pair Plot

Chart: Pair Plot

# %%
sns.pairplot(df[['age','fare','sibsp','parch','survived']],hue = 'survived',palette = {0:'red',1:'green'})

# %%
8.Categorical Features

Chart: Count Plot

# %%
sns.countplot(x='alone', data=df, hue ='sex')
# Out:
# <Axes: xlabel='alone', ylabel='count'>

# %%
sns.stripplot(x=df['embark_town'] ,y = df['age'], data=df, palette=['green','purple','red'],hue = 'who')
# Out:
# <Axes: xlabel='embark_town', ylabel='age'>
